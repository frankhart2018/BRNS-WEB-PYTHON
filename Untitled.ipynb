# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
im = cv2.imread("static/colorized/exp246.png")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
fig, ax = plt.subplots(1, figsize=(15, 10))
ax.imshow(im)

rect = patches.Rectangle((403, 239), 10, 10, linewidth=1, edgecolor='y', facecolor='none')
ax.add_patch(rect)

# %%
im.shape
# Out:
# (512, 640, 3)
