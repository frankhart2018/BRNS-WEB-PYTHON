# %%
import cv2

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
im = cv2.imread("jaccard-images/exp251.jpg")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
fig, ax = plt.subplots(1, figsize=(15, 10))
ax.imshow(im)

rect = patches.Rectangle((420, 280), 10, 10, linewidth=1, edgecolor='r', facecolor='none')
ax.add_patch(rect)

# %%
metal = im[280:290, 420:430].ravel()

np.save(f"{dir_name}/metal.npy", metal)

# %%
inorganic = im[340:350, 500:510].ravel()

np.save(f"{dir_name}/inorganic.npy", inorganic)

# %%
organic = im[340:350, 350:360].ravel()

np.save(f"{dir_name}/organic.npy", organic)

# %%
type_1 = im[200:210, 270:280].ravel()
type_2 = im[310:320, 270:280].ravel()
type_3 = im[310:320, 440:450].ravel()
type_4 = im[310:320, 520:530].ravel()
type_5 = im[310:320, 580:590].ravel()
type_6 = im[210:220, 550:560].ravel()
type_7 = im[210:220, 450:460].ravel()

# %%
assert len(type_1) == len(type_2) == len(type_3) == len(type_4) == len(type_5) == len(type_6) == len(type_7)

# %%
import numpy as np

# %%
import os

dir_name = "jaccard-vectors"
if not os.path.exists(dir_name):
    os.mkdir(dir_name)
    
np.save(f"{dir_name}/type-1.npy", type_1)
np.save(f"{dir_name}/type-2.npy", type_2)
np.save(f"{dir_name}/type-3.npy", type_3)
np.save(f"{dir_name}/type-4.npy", type_4)
np.save(f"{dir_name}/type-5.npy", type_5)
np.save(f"{dir_name}/type-6.npy", type_6)
np.save(f"{dir_name}/type-7.npy", type_7)
